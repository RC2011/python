# %%
import sys

from mc_remote.minecraft import Minecraft
import param_mc_remote as param
from param_mc_remote import PLAYER_ORIGIN as PO
from param_mc_remote import block
from lcd_font_mc_mozi import LCD_font as LCD_font
from lcd_font_mc_mozi import LCD_font_styles
from datetime import datetime
from time import sleep

# %%
mc = Minecraft.create(address=param.ADRS_MCR, port=param.PORT_MCR)
result = mc.setPlayer(param.PLAYER_NAME, PO.x, PO.y, PO.z)
if ("Error" in result):
    sys.exit(result)
else:
    print(result)
# Out:
# Player Bananadaizin set to location: 2000, 0, 2000 in world "world"
# Player Bananadaizin set to location: 2000, 0, 2000 in world "world"

# %%
display1 = LCD_font(mc)
display1.init_col(COLOR_ON=param.block.DIAMOND_BLOCK, COLOR_OFF=param.block.AIR)
display1.init_row(X_ORG=-40, Y_ORG=param.Y_SEA + 30, Z_ORG=-40, COL_INTV=6)

# %%
#12=!,13=?,14=A,15=B,16=C,17=D,18=E,19=F,20=G,21=H,22=I,23=J,24=K
#25=L,26=M,27=N,28=O,29=P,30=Q,31=R,32=S,33=T,34=U,35=V,36=W,37=X
#38=Y,39=Z,40=a,41=b,42=c,43=d,44=e,45=f,46=g,47=h,48=i,49=j,50=k
#51=l,52=m,53=n,54=o,55=p,56=q,57=r,58=s,59=t,60=u,61=v,62=w,63=x
#64=y,65=z,66=',67=.

# %%
display1.update_col(col=0, code=21)
display1.update_col(col=1, code=44)
display1.update_col(col=2, code=51)
display1.update_col(col=3, code=51)
display1.update_col(col=4, code=54)
display1.update_col(col=6, code=62)
display1.update_col(col=7, code=54)
display1.update_col(col=8, code=57)
display1.update_col(col=9, code=51)
display1.update_col(col=10, code=43)
display1.update_col(col=11, code=12)
