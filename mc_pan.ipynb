# %%
import sys
from lcd_font_mc_pan import LCD_font_styles
from lcd_font_mc_pan import LCD_font
from mc_remote.minecraft import Minecraft
import param_mc_remote as param
from param_mc_remote import PLAYER_ORIGIN as PO
from param_mc_remote import block
from time import sleep
from pygame.locals import *
from pygame.locals import Rect
from random import random
# Out:
# param_mc_remote loaded for Bananadaizin at 2000, 0, 2000
# pygame-ce 2.5.3 (SDL 2.30.12, Python 3.11.9)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import sys
# ----> 2 from lcd_font_mc_pan import LCD_font_styles
#       3 from lcd_font_mc_pan import LCD_font
#       4 from mc_remote.minecraft import Minecraft
#
# File c:\Users\rc\.vscode\python\lcd_font_mc_pan.py:431
#     427 YELLOW = (250, 250, 20)
#     428 WHITE = (250, 250, 250)
# --> 431 class LCD_font():
#     432     def __init__(self, mc):
#     433         self.mc = mc
#
# File c:\Users\rc\.vscode\python\lcd_font_mc_pan.py:447, in LCD_font()
#     444     self.COLOR_ON = COLOR_ON
#     445     self.COLOR_OFF = COLOR_OFF
# --> 447 def init_col(self, BLOCK_SIZE=4, BLOCK_INTV=4, COLOR_ON=WHITE, COLOR_OFF=BLUE):
#     448     # ひと桁、コラムの設定
#     449     # ブロックのサイズと配置間隔をピクセル指定（インターバル）
# ...

# %%
mc = Minecraft.create(address=param.ADRS_MCR, port=param.PORT_MCR)
result = mc.setPlayer(param.PLAYER_NAME, PO.x, PO.y, PO.z)
if ("Error" in result):
    sys.exit(result)
else:
    print(result)
# Out:
# Player Bananadaizin set to location: 2000, 0, 2000 in world "world"
# Player Bananadaizin set to location: 2000, 0, 2000 in world "world"

# %%
lcd14 = LCD_font(mc)
lcd14.init_col(COLOR_ON=param.block.BLACK_CONCRETE, COLOR_OFF=param.block.GREEN_CONCRETE)
lcd14.init_row(X_ORG=-48, Y_ORG=69, Z_ORG=-30, COL_INTV=6)

lcd15 = LCD_font(mc)
lcd15.init_col(COLOR_ON=param.block.BLACK_CONCRETE, COLOR_OFF=param.block.GREEN_CONCRETE)
lcd15.init_row(X_ORG=-48, Y_ORG=69, Z_ORG=-30, COL_INTV=6)

lcd16 = LCD_font(mc)
lcd16.init_col(COLOR_ON=param.block.BLACK_CONCRETE, COLOR_OFF=param.block.GREEN_CONCRETE)
lcd16.init_row(X_ORG=-48, Y_ORG=69, Z_ORG=-30, COL_INTV=6)

lcd17 = LCD_font(mc)
lcd17.init_col(COLOR_ON=param.block.BLACK_CONCRETE, COLOR_OFF=param.block.GREEN_CONCRETE)
lcd17.init_row(X_ORG=-48, Y_ORG=69, Z_ORG=-30, COL_INTV=6)

lcd18 = LCD_font(mc)
lcd18.init_col(COLOR_ON=param.block.BLACK_CONCRETE, COLOR_OFF=param.block.GREEN_CONCRETE)
lcd18.init_row(X_ORG=-48, Y_ORG=69, Z_ORG=-30, COL_INTV=6)

lcd19 = LCD_font(mc)
lcd19.init_col(COLOR_ON=param.block.BLACK_CONCRETE, COLOR_OFF=param.block.GREEN_CONCRETE)
lcd19.init_row(X_ORG=-48, Y_ORG=69, Z_ORG=-30, COL_INTV=6)

lcd20 = LCD_font(mc)
lcd20.init_col(COLOR_ON=param.block.BLACK_CONCRETE, COLOR_OFF=param.block.GREEN_CONCRETE)
lcd20.init_row(X_ORG=-48, Y_ORG=69, Z_ORG=-30, COL_INTV=6)

lcd21 = LCD_font(mc)
lcd21.init_col(COLOR_ON=param.block.BLACK_CONCRETE, COLOR_OFF=param.block.GREEN_CONCRETE)
lcd21.init_row(X_ORG=-48, Y_ORG=69, Z_ORG=-30, COL_INTV=6)

lcd22 = LCD_font(mc)
lcd22.init_col(COLOR_ON=param.block.BLACK_CONCRETE, COLOR_OFF=param.block.GREEN_CONCRETE)
lcd22.init_row(X_ORG=-48, Y_ORG=69, Z_ORG=-30, COL_INTV=6)

lcd23 = LCD_font(mc)
lcd23.init_col(COLOR_ON=param.block.BLACK_CONCRETE, COLOR_OFF=param.block.GREEN_CONCRETE)
lcd23.init_row(X_ORG=-48, Y_ORG=69, Z_ORG=-30, COL_INTV=6)

lcd2 = LCD_font(mc)
lcd2.init_col(COLOR_ON=param.block.BLACK_CONCRETE, COLOR_OFF=param.block.BLUE_CONCRETE)
lcd2.init_row(X_ORG=-48, Y_ORG=151, Z_ORG=8, COL_INTV=6)

lcd3 = LCD_font(mc)
lcd3.init_col(COLOR_ON=param.block.BLACK_CONCRETE, COLOR_OFF=param.block.BLUE_CONCRETE)
lcd3.init_row(X_ORG=-48, Y_ORG=151, Z_ORG=8, COL_INTV=6)

lcd4 = LCD_font(mc)
lcd4.init_col(COLOR_ON=param.block.BLACK_CONCRETE, COLOR_OFF=param.block.BLUE_CONCRETE)
lcd4.init_row(X_ORG=-48, Y_ORG=151, Z_ORG=8, COL_INTV=6)

lcd5 = LCD_font(mc)
lcd5.init_col(COLOR_ON=param.block.BLACK_CONCRETE, COLOR_OFF=param.block.BLUE_CONCRETE)
lcd5.init_row(X_ORG=-48, Y_ORG=151, Z_ORG=8, COL_INTV=6)

lcd6 = LCD_font(mc)
lcd6.init_col(COLOR_ON=param.block.BLACK_CONCRETE, COLOR_OFF=param.block.BLUE_CONCRETE)
lcd6.init_row(X_ORG=-48, Y_ORG=151, Z_ORG=8, COL_INTV=6)

lcd7 = LCD_font(mc)
lcd7.init_col(COLOR_ON=param.block.BLACK_CONCRETE, COLOR_OFF=param.block.BLUE_CONCRETE)
lcd7.init_row(X_ORG=-48, Y_ORG=151, Z_ORG=8, COL_INTV=6)

lcd8 = LCD_font(mc)
lcd8.init_col(COLOR_ON=param.block.BLACK_CONCRETE, COLOR_OFF=param.block.BLUE_CONCRETE)
lcd8.init_row(X_ORG=-48, Y_ORG=151, Z_ORG=8, COL_INTV=6)

lcd24 = LCD_font(mc)
lcd24.init_col(COLOR_ON=param.block.WHITE_CONCRETE, COLOR_OFF=param.block.BLACK_CONCRETE)
lcd24.init_row(X_ORG=-48, Y_ORG=150, Z_ORG=-20, COL_INTV=6)

lcd25 = LCD_font(mc)
lcd25.init_col(COLOR_ON=param.block.WHITE_CONCRETE, COLOR_OFF=param.block.BLACK_CONCRETE)
lcd25.init_row(X_ORG=-48, Y_ORG=150, Z_ORG=-20, COL_INTV=6)

lcd9 = LCD_font(mc)
lcd9.init_col(COLOR_ON=param.block.WHITE_CONCRETE, COLOR_OFF=param.block.BLACK_CONCRETE)
lcd9.init_row(X_ORG=-48, Y_ORG=135, Z_ORG=19, COL_INTV=6)

lcd10 = LCD_font(mc)
lcd10.init_col(COLOR_ON=param.block.WHITE_CONCRETE, COLOR_OFF=param.block.BLACK_CONCRETE)
lcd10.init_row(X_ORG=-48, Y_ORG=135, Z_ORG=19, COL_INTV=6)

lcd11 = LCD_font(mc)
lcd11.init_col(COLOR_ON=param.block.WHITE_CONCRETE, COLOR_OFF=param.block.BLACK_CONCRETE)
lcd11.init_row(X_ORG=-48, Y_ORG=135, Z_ORG=19, COL_INTV=6)

lcd12 = LCD_font(mc)
lcd12.init_col(COLOR_ON=param.block.WHITE_CONCRETE, COLOR_OFF=param.block.BLACK_CONCRETE)
lcd12.init_row(X_ORG=-48, Y_ORG=135, Z_ORG=19, COL_INTV=6)

lcd13 = LCD_font(mc)
lcd13.init_col(COLOR_ON=param.block.WHITE_CONCRETE, COLOR_OFF=param.block.BLACK_CONCRETE)
lcd13.init_row(X_ORG=-48, Y_ORG=135, Z_ORG=19, COL_INTV=6)

lcd33 = LCD_font(mc)
lcd33.init_col(COLOR_ON=param.block.WHITE_CONCRETE, COLOR_OFF=param.block.BLACK_CONCRETE)
lcd33.init_row(X_ORG=-48, Y_ORG=123, Z_ORG=25, COL_INTV=6)

lcd34 = LCD_font(mc)
lcd34.init_col(COLOR_ON=param.block.WHITE_CONCRETE, COLOR_OFF=param.block.BLACK_CONCRETE)
lcd34.init_row(X_ORG=-48, Y_ORG=123, Z_ORG=25, COL_INTV=6)

lcd35 = LCD_font(mc)
lcd35.init_col(COLOR_ON=param.block.WHITE_CONCRETE, COLOR_OFF=param.block.BLACK_CONCRETE)
lcd35.init_row(X_ORG=-48, Y_ORG=123, Z_ORG=25, COL_INTV=6)

lcd60 = LCD_font(mc)
lcd60.init_col(COLOR_ON=param.block.WHITE_CONCRETE, COLOR_OFF=param.block.BLACK_CONCRETE)
lcd60.init_row(X_ORG=-48, Y_ORG=111, Z_ORG=25, COL_INTV=6)

lcd61 = LCD_font(mc)
lcd61.init_col(COLOR_ON=param.block.WHITE_CONCRETE, COLOR_OFF=param.block.BLACK_CONCRETE)
lcd61.init_row(X_ORG=-48, Y_ORG=111, Z_ORG=25, COL_INTV=6)

lcd62 = LCD_font(mc)
lcd62.init_col(COLOR_ON=param.block.WHITE_CONCRETE, COLOR_OFF=param.block.BLACK_CONCRETE)
lcd62.init_row(X_ORG=-48, Y_ORG=111, Z_ORG=25, COL_INTV=6)

lcd63 = LCD_font(mc)
lcd63.init_col(COLOR_ON=param.block.WHITE_CONCRETE, COLOR_OFF=param.block.BLACK_CONCRETE)
lcd63.init_row(X_ORG=-48, Y_ORG=111, Z_ORG=25, COL_INTV=6)

# %%
panseisan = 1
panseisankane = 50
panseisanhyouzi = 0
koeta = 0
zikan = 2
kieru = 0
pannnokazu = 957
kanenoryou = 5
panseisanurikire = 0
urinekane = 50
urineurikire = 0
urinehyouzi = 0
torofiurikire = 0
torofikane = 9999999999
torofi = 0
torofihyouzi = 0

# %%
code9 = 55
code10 = 60
code11 = 75
code12 = 74
code13 = 73
code14 = 573
code15 = 0
code16 = 0
code17 = 0
code18 = 0
code19 = 0
code20 = 0
code21 = 0
code22 = 0
code23 = 0
code24 = 70
code25 = 69
code26 = 38
code27 = 69
code28 = 71
code29 = 72
code30 = 79
code31 = 78
code32 = 77
code33 = 76
kaisu = 0
yokonoookisa = 2

# %%
def DisplayMochiGaneNum(code14):
    lcd14.update_col(col=0, code=code14%10)
    sleep(0.1)
    lcd15.update_col(col=1, code=code14/10%10)
    sleep(0.1)
    lcd16.update_col(col=2, code=code14/100%10)
    sleep(0.1)
    lcd17.update_col(col=3, code=code14/1000%10)
    sleep(0.1)
    lcd18.update_col(col=4, code=code14/10000%10)
    sleep(0.1)
    lcd19.update_col(col=5, code=code14/100000%10)
    sleep(0.1)
    lcd20.update_col(col=6, code=code14/1000000%10)
    sleep(0.1)
    lcd21.update_col(col=7, code=code14/10000000%10)
    sleep(0.1)
    lcd22.update_col(col=8, code=code14/100000000%10)
    sleep(0.1)
    lcd23.update_col(col=9, code=code14/1000000000%10)
    sleep(0.1)
def DisplayPanNum(pannnokazu):
     lcd2.update_col(col=0, code=pannnokazu%10)
     sleep(0.1)
     lcd3.update_col(col=1, code=pannnokazu/10%10)
     sleep(0.1)
     lcd4.update_col(col=2, code=pannnokazu/100%10)
     sleep(0.1)
     lcd5.update_col(col=3, code=pannnokazu/1000%10)
     sleep(0.1)
     lcd6.update_col(col=4, code=pannnokazu/10000%10)
     sleep(0.1)
     lcd7.update_col(col=5, code=pannnokazu/100000%10)
     sleep(0.1)
     lcd8.update_col(col=6, code=pannnokazu/1000000%10)
     sleep(0.1)

# %%
x, y, z = -48, param.Y_SEA + 1, -34

# %%
for _i in range(80):
    for _i in range(30):
        mc.setBlock(x, y, z, block.GREEN_CONCRETE)
        sleep(0.0001)
        y += 1
    z +=1
    y -=30
x, y, z = -48, param.Y_SEA + 31, -34
for _i in range(80):
    for _i in range(60):
        mc.setBlock(x, y, z, block.BLUE_CONCRETE)
        sleep(0.0001)
        y += 1
    z +=1
    y -=60

# %%
x, y, z = -48, param.Y_SEA + 9, 20
for _i in range(22):
    for _i in range(yokonoookisa):
        mc.setBlock(x, y, z, block.LIME_CONCRETE)
        sleep(0.001)
        z += 1
    y += 1
    kaisu += 1
    if kaisu == 1:
        z -= yokonoookisa + 2
        yokonoookisa += 4
    if kaisu == 2:
        z -= yokonoookisa + 2
        yokonoookisa += 4
    if kaisu == 3:
        z -= yokonoookisa + 2
        yokonoookisa += 4
    if kaisu == 4:
        z -= yokonoookisa + 1
        yokonoookisa += 2
    if kaisu == 5:
        z -= yokonoookisa
    if kaisu == 6:
        z -= yokonoookisa + 1
        yokonoookisa += 2
    if kaisu == 7:
        z -= yokonoookisa
    if kaisu == 8:
        z -= yokonoookisa + 1
        yokonoookisa += 2
    if kaisu == 9:
        z -= yokonoookisa
    if kaisu == 10:
        z -= yokonoookisa + 1
        yokonoookisa += 2
    if kaisu == 11:
        z -= yokonoookisa
    if kaisu == 12:
        z -= yokonoookisa - 1
        yokonoookisa -= 2
    if kaisu == 13:
        z -= yokonoookisa
    if kaisu == 14:
        z -= yokonoookisa - 1
        yokonoookisa -= 2
    if kaisu == 15:
        z -= yokonoookisa
    if kaisu == 16:
        z -= yokonoookisa - 1
        yokonoookisa -= 2
    if kaisu == 17:
        z -= yokonoookisa
    if kaisu == 18:
        z -= yokonoookisa - 1
        yokonoookisa -= 2
    if kaisu == 19:
        z -= yokonoookisa - 2
        yokonoookisa -= 4
    if kaisu == 20:
        z -= yokonoookisa - 2
        yokonoookisa -= 4
    if kaisu == 21:
        z -= yokonoookisa - 2
        yokonoookisa -= 4

# %%
x, y, z = -48, param.Y_SEA + 9, -10
kaisu = 0
yokonoookisa = 2
for _i in range(22):
    for _i in range(yokonoookisa):
        mc.setBlock(x, y, z, block.LIME_CONCRETE)
        sleep(0.001)
        z += 1
    y += 1
    kaisu += 1
    if kaisu == 1:
        z -= yokonoookisa + 2
        yokonoookisa += 4
    if kaisu == 2:
        z -= yokonoookisa + 2
        yokonoookisa += 4
    if kaisu == 3:
        z -= yokonoookisa + 2
        yokonoookisa += 4
    if kaisu == 4:
        z -= yokonoookisa + 1
        yokonoookisa += 2
    if kaisu == 5:
        z -= yokonoookisa
    if kaisu == 6:
        z -= yokonoookisa + 1
        yokonoookisa += 2
    if kaisu == 7:
        z -= yokonoookisa
    if kaisu == 8:
        z -= yokonoookisa + 1
        yokonoookisa += 2
    if kaisu == 9:
        z -= yokonoookisa
    if kaisu == 10:
        z -= yokonoookisa + 1
        yokonoookisa += 2
    if kaisu == 11:
        z -= yokonoookisa
    if kaisu == 12:
        z -= yokonoookisa - 1
        yokonoookisa -= 2
    if kaisu == 13:
        z -= yokonoookisa
    if kaisu == 14:
        z -= yokonoookisa - 1
        yokonoookisa -= 2
    if kaisu == 15:
        z -= yokonoookisa
    if kaisu == 16:
        z -= yokonoookisa - 1
        yokonoookisa -= 2
    if kaisu == 17:
        z -= yokonoookisa
    if kaisu == 18:
        z -= yokonoookisa - 1
        yokonoookisa -= 2
    if kaisu == 19:
        z -= yokonoookisa - 2
        yokonoookisa -= 4
    if kaisu == 20:
        z -= yokonoookisa - 2
        yokonoookisa -= 4
    if kaisu == 21:
        z -= yokonoookisa - 2
        yokonoookisa -= 4

# %%
x, y, z = -48, param.Y_SEA + 9, -10
for _i in range(30):
    for _i in range(22):
        mc.setBlock(x, y, z, block.LIME_CONCRETE)
        sleep(0.001)
        y += 1
    z +=1
    y -=22

# %%
x, y, z = -48, param.Y_SEA + 20, -6
for _i in range(4):
    for _i in range(11):
        mc.setBlock(x, y, z, block.LIGHT_GRAY_CONCRETE)
        sleep(0.001)
        y += 1
    z +=1
    y -=11
x, y, z = -48, param.Y_SEA + 20, 4
for _i in range(4):
    for _i in range(11):
        mc.setBlock(x, y, z, block.LIGHT_GRAY_CONCRETE)
        sleep(0.001)
        y += 1
    z +=1
    y -=11
x, y, z = -48, param.Y_SEA + 20, 14
for _i in range(4):
    for _i in range(11):
        mc.setBlock(x, y, z, block.LIGHT_GRAY_CONCRETE)
        sleep(0.001)
        y += 1
    z +=1
    y -=11
x, y, z = -48, param.Y_SEA + 81, -25
for _i in range(13):
    for _i in range(9):
        mc.setBlock(x, y, z, block.BLACK_CONCRETE)
        sleep(0.001)
        y += 1
    z +=1
    y -=9
x, y, z = -48, param.Y_SEA + 66, 14
for _i in range(31):
    for _i in range(9):
        mc.setBlock(x, y, z, block.BLACK_CONCRETE)
        sleep(0.001)
        y += 1
    z +=1
    y -=9
x, y, z = -48, param.Y_SEA + 54, 14
for _i in range(31):
    for _i in range(9):
        mc.setBlock(x, y, z, block.BLACK_CONCRETE)
        sleep(0.001)
        y += 1
    z +=1
    y -=9
x, y, z = -48, param.Y_SEA + 42, 14
for _i in range(31):
    for _i in range(9):
        mc.setBlock(x, y, z, block.BLACK_CONCRETE)
        sleep(0.001)
        y += 1
    z +=1
    y -=9

# %%
DisplayMochiGaneNum(code14)
DisplayPanNum(pannnokazu)
lcd24.update_col(col=0, code=code24)
sleep(0.1)
lcd25.update_col(col=1, code=code25)
sleep(0.1)
lcd9.update_col(col=0, code=code9)
sleep(0.1)
lcd10.update_col(col=1, code=code10)
sleep(0.1)
lcd11.update_col(col=2, code=code11)
sleep(0.1)
lcd12.update_col(col=3, code=code12)
sleep(0.1)
lcd13.update_col(col=4, code=code13)
sleep(0.1)
lcd33.update_col(col=2, code=code27)
sleep(0.1)
lcd34.update_col(col=1, code=code28)
sleep(0.1)
lcd35.update_col(col=0, code=code29)
sleep(0.1)
lcd60.update_col(col=0, code=code30)
sleep(0.1)
lcd61.update_col(col=1, code=code31)
sleep(0.1)
lcd62.update_col(col=2, code=code32)
sleep(0.1)
lcd63.update_col(col=3, code=code33)
sleep(0.1)
mc.setBlock()
